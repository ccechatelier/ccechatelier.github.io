# %%
from scholarly import scholarly
from scholarly import ProxyGenerator

import json

pg = ProxyGenerator()
pg.FreeProxies()
scholarly.use_proxy(pg)

print("[INFO] Searching for the author ...")
# Search for the author
author = scholarly.search_author_id(id = 'JMdqN-sAAAAJ',  filled = True, sortby = "year")
# author = next(search_query)

print("[INFO] Collecting data ...")
# Fill the author's profile
# author = scholarly.fill(author)

print("[INFO] Extracting data ...")
# Extract relevant data
profile_data = {
    "name": author['name'],
    "affiliation": author.get('affiliation', 'N/A'),
    "h_index": author.get('hindex', 'N/A'),
    "i10_index": author.get('i10index', 'N/A'),
    "citations": author.get('citedby', 'N/A'),
    "citations_per_year": author.get('cites_per_year', 'N/A'),
    "publications": []
}

index = 1
for pub in author['publications']:
    publication = scholarly.fill(pub)

    if publication['bib'].get('conference', 'N/A') == 'N/A' and publication['bib'].get('publisher', 'N/A') != 'N/A'  and publication['bib'].get('journal', 'N/A') != 'N/A' :
        print(index, publication['bib'].get('journal', 'N/A'), publication['bib'].get('publisher', 'N/A'), publication['bib'].get('conference', 'N/A'))
        profile_data["publications"].append({
        "index": index,
        "title": publication['bib']['title'],
        "journal": publication['bib'].get('journal', 'N/A'),
        "publisher": publication['bib'].get('publisher', 'N/A'),
        "conference": publication['bib'].get('conference', 'N/A'),
        "year": publication['bib'].get('pub_year', 'N/A'),
        "citation": publication['num_citations']
        })
        index += 1
        
    if publication['bib'].get('conference', 'N/A') == 'N/A' and publication['bib'].get('publisher', 'N/A') == 'N/A'  and publication['bib'].get('journal', 'N/A') == 'N/A' :
        print(index, publication['bib'].get('journal', 'N/A'), publication['bib'].get('publisher', 'N/A'), publication['bib'].get('conference', 'N/A'))
        profile_data["publications"].append({
        "index": index,
        "title": publication['bib']['title'],
        "journal": publication['bib'].get('journal', 'N/A'),
        "publisher": publication['bib'].get('publisher', 'N/A'),
        "conference": publication['bib'].get('conference', 'N/A'),
        "year": publication['bib'].get('pub_year', 'N/A'),
        "citation": publication['num_citations']
        })
        index += 1

profile_data_bis = {
    "name": author['name'],
    "affiliation": author.get('affiliation', 'N/A'),
    "h_index": author.get('hindex', 'N/A'),
    "i10_index": author.get('i10index', 'N/A'),
    "citations": author.get('citedby', 'N/A'),
    "citations_per_year": author.get('cites_per_year', 'N/A'),
    "publications": []
}

print("[INFO] Saving the data ...")
# Save the data as a JSON file
with open('scholar_profile_intermediaire.json', 'w') as f:
    json.dump(profile_data, f)

index -= 1
for pub in author['publications']:
    publication = scholarly.fill(pub)

    if publication['bib'].get('conference', 'N/A') == 'N/A' and publication['bib'].get('publisher', 'N/A') != 'N/A'  and publication['bib'].get('journal', 'N/A') != 'N/A' :
        print(index, publication['bib'].get('journal', 'N/A'), publication['bib'].get('publisher', 'N/A'), publication['bib'].get('conference', 'N/A'))
        profile_data_bis["publications"].append({
        "index": index,
        "title": publication['bib']['title'],
        "journal": publication['bib'].get('journal', 'N/A'),
        "publisher": publication['bib'].get('publisher', 'N/A'),
        "conference": publication['bib'].get('conference', 'N/A'),
        "year": publication['bib'].get('pub_year', 'N/A'),
        "citation": publication['num_citations']
        })
        index -= 1
        
    if publication['bib'].get('conference', 'N/A') == 'N/A' and publication['bib'].get('publisher', 'N/A') == 'N/A'  and publication['bib'].get('journal', 'N/A') == 'N/A' :
        print(index, publication['bib'].get('journal', 'N/A'), publication['bib'].get('publisher', 'N/A'), publication['bib'].get('conference', 'N/A'))
        profile_data_bis["publications"].append({
        "index": index,
        "title": publication['bib']['title'],
        "journal": publication['bib'].get('journal', 'N/A'),
        "publisher": publication['bib'].get('publisher', 'N/A'),
        "conference": publication['bib'].get('conference', 'N/A'),
        "year": publication['bib'].get('pub_year', 'N/A'),
        "citation": publication['num_citations']
        })
        index -= 1

print("[INFO] Saving the data ...")
# Save the data as a JSON file
with open('scholar_profile.json', 'w') as f:
    json.dump(profile_data_bis, f)

print("Profile data saved to scholar_profile.json")
# Out:
# [INFO] Searching for the author ...
# [INFO] Collecting data ...
# [INFO] Extracting data ...
# 1 Applied Catalysis B: Environment and Energy Elsevier N/A
# 2 Acta Materialia Pergamon N/A
# 3 ACS Applied Energy Materials American Chemical Society N/A
# 4 Journal of the American Chemical Society American Chemical Society N/A
# 5 ACS Nano American Chemical Society N/A
# 6 ACS Nano American Chemical Society N/A
# 7 ACS Applied Nano Materials American Chemical Society N/A
# 8 Nature Materials Nature Publishing Group UK N/A
# 9 ACS applied materials & interfaces American Chemical Society N/A
# 10 Journal of Applied Crystallography International Union of Crystallography N/A
# 11 Nature Communications Nature Publishing Group UK N/A
# 12 Nanoscale The Royal Society of Chemistry N/A
# 13 N/A N/A N/A
# 14 The Journal of Physical Chemistry C American Chemical Society N/A
# 15 ACS Applied Materials & Interfaces American Chemical Society N/A
# 16 The Journal of Physical Chemistry C American Chemical Society N/A
# 17 Journal of Materials Chemistry A Royal Society of Chemistry N/A
# 18 Science and technology of advanced materials Taylor & Francis N/A
# 19 Acta Crystallographica Section A: Foundations and Advances International Union of Crystallography N/A
# 20 Crystals Multidisciplinary Digital Publishing Institute N/A
# 21 N/A N/A N/A
# 22 Physical Review B American Physical Society N/A
# 23 N/A N/A N/A
# [INFO] Saving the data ...
# 23 Applied Catalysis B: Environment and Energy Elsevier N/A
# 22 Acta Materialia Pergamon N/A
# 21 ACS Applied Energy Materials American Chemical Society N/A
# 20 Journal of the American Chemical Society American Chemical Society N/A
# 19 ACS Nano American Chemical Society N/A
# 18 ACS Nano American Chemical Society N/A
# 17 ACS Applied Nano Materials American Chemical Society N/A
# 16 Nature Materials Nature Publishing Group UK N/A
# 15 ACS applied materials & interfaces American Chemical Society N/A
# 14 Journal of Applied Crystallography International Union of Crystallography N/A
# 13 Nature Communications Nature Publishing Group UK N/A
# 12 Nanoscale The Royal Society of Chemistry N/A
# 11 N/A N/A N/A
# 10 The Journal of Physical Chemistry C American Chemical Society N/A
# 9 ACS Applied Materials & Interfaces American Chemical Society N/A
# 8 The Journal of Physical Chemistry C American Chemical Society N/A
# 7 Journal of Materials Chemistry A Royal Society of Chemistry N/A
# 6 Science and technology of advanced materials Taylor & Francis N/A
# 5 Acta Crystallographica Section A: Foundations and Advances International Union of Crystallography N/A
# 4 Crystals Multidisciplinary Digital Publishing Institute N/A
# 3 N/A N/A N/A
# 2 Physical Review B American Physical Society N/A
# 1 N/A N/A N/A
# [INFO] Saving the data ...
# Profile data saved to scholar_profile.json

# %%
with open('scholar_profile_intermediaire.json', 'r') as file:
    data = json.load(file)
    publications = data['publications']

# %%
for pub in publications:
    pub['index'] = len(publications) - pub['index'] + 1

# %%
# Save the updated publications data to the JSON file
with open('scholar_profile_v2.json', 'w') as f:
    data['publications'] = publications
    json.dump(data, f, indent=2)

print("[INFO] Updated scholar_profile_v2.json with new publication indices")
# Out:
# [INFO] Updated scholar_profile_v2.json with new publication indices
